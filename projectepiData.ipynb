# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#lecture notre bd w7atinehe fi events (variable sou forme de liste)
events = pd.read_csv("data/Lionel Messi - All Goals for Barcelona.csv")
#Affichage d'informations sur le bloc de données
events.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 672 entries, 0 to 671
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        672 non-null    int64
#  1   Season            672 non-null    object
#  2   Competition       672 non-null    object
#  3   Matchday          672 non-null    object
#  4   Date              672 non-null    object
#  5   Venue             672 non-null    object
#  6   Club              672 non-null    object
#  7   Opponent          672 non-null    object
#  8   Result            672 non-null    object
#  9   Playing_Position  672 non-null    object
#  10  Minute            672 non-null    object
#  11  At_score          672 non-null    object
#  12  Type              671 non-null    object
#  13  Goal_assist       466 non-null    object
#  14  Year              672 non-null    int64
#  15  Month             672 non-null    object
# ...

# %%
events.head(10)
# Out:
#    Unnamed: 0 Season            Competition        Matchday      Date Venue  \
# 0           0  04/05                 LaLiga              34    5/1/05     H
# 1           1  05/06  UEFA Champions League     Group Stage   11/2/05     H
# 2           2  05/06                 LaLiga              13  11/27/05     H
# 3           3  05/06                 LaLiga              19   1/15/06     H
# 4           4  05/06                 LaLiga              20   1/22/06     H
# 5           5  05/06                 LaLiga              21   1/29/06     A
# 6           6  05/06                 LaLiga              21   1/29/06     A
# 7           7  05/06           Copa del Rey  Quarter-Finals    2/1/06     H
# 8           8  05/06                 LaLiga              24   2/18/06     H
# 9           9  06/07                 LaLiga               1   8/28/06     A
#
#            Club              Opponent Result Playing_Position Minute At_score  \
# ...

# %% [markdown]
# Affichage de la forme du bloc de données

# %%
events.shape
# Out:
# (672, 16)

# %% [markdown]
# Affichage des colonnes du bloc de données

# %%
events.columns
# Out:
# Index(['Unnamed: 0', 'Season', 'Competition', 'Matchday', 'Date', 'Venue',
#        'Club', 'Opponent', 'Result', 'Playing_Position', 'Minute', 'At_score',
#        'Type', 'Goal_assist', 'Year', 'Month'],
#       dtype='object')

# %% [markdown]
# Affichage de certaines informations décrivant le bloc de données

# %%
events.describe(include=['object']).T
# Out:
#                  count unique               top freq
# Season             672     17             11/12   73
# Competition        672      6            LaLiga  474
# Matchday           672     46       Group Stage   71
# Date               672    431            3/7/12    5
# Venue              672      2                 H  402
# Club               672      1      FC Barcelona  672
# Opponent           672     81        Sevilla FC   38
# Result             672     46               4:0   45
# Playing_Position   672      9                CF  261
# Minute             672     96                55   13
# At_score           672     38               1:0   95
# Type               671     12  Left-footed shot  413
# Goal_assist        466     62       Luis Suarez   48
# Month              672     12           January   93

# %% [markdown]
# توزيع الأهداف على المواسم

# %%
# Tracer  pour montrer la distribution des buts sur les saisons et les années civiles
fig, axes = plt.subplots(2, 1, figsize = (25,25))

# The Distribution of Goals among the Seasons (Bar Chart)
seasons = events.Season.value_counts().sort_index()
axes[0].bar(seasons.index, seasons.values, color = ['#6ee1fa', '#65d4ee', '#54b9d7', '#5cc6e3', '#449fbf', '#2d7a9b', '#1f6282',
                                                    '#003653', '#07415f', '#3c93b3', '#104c6b', '#3c93b3', '#175776', '#3586a7',
                                                    '#266e8f', '#4caccb', '#449fbf'])
axes[0].set_title('Goals Distribution over Seasons', size = 36)
axes[0].set_xlabel('Season', size = 24)
axes[0].set_ylabel('Goals', size = 24)
axes[0].patch.set_facecolor('#F2F2F2')
axes[0].tick_params(labelrotation = 75, labelsize = 20)
axes[0].spines['bottom'].set_color('black')
axes[0].spines['left'].set_color('black')
axes[0].spines['top'].set_color('black')
axes[0].spines['right'].set_color('black')

# The Distribution of Goals among the calendar Years (Bar Chart)
years = events.Year.value_counts().sort_index()
axes[1].bar(years.index, years.values, color = ['#6ee1fa', '#65d4ee', '#54b9d7', '#5cc6e3', '#3c93b3', '#07415f', '#104c6b',
                                                '#003653', '#3586a7', '#1f6282', '#266e8f', '#175776', '#1f6282', '#266e8f',
                                                '#2d7a9b', '#4caccb', '#449fbf'])
axes[1].set_title('Goals Distribution over Calender Years', size = 36)
axes[1].set_xlabel('Year', size = 24)
axes[1].set_ylabel('Goals', size = 24)
axes[1].patch.set_facecolor('#F2F2F2')
axes[1].tick_params(labelrotation = 75, labelsize = 20)
axes[1].locator_params('x', nbins = 34)
axes[1].spines['bottom'].set_color('black')
axes[1].spines['left'].set_color('black')
axes[1].spines['top'].set_color('black')
axes[1].spines['right'].set_color('black')

# %%
sns.set(rc={'figure.figsize':(20,8)})
plt.xticks(rotation = 90, fontsize = 16)
p = sns.countplot(events['Season'], hue_order = events.groupby('Competition'))
p.axes.set_title("Goals per season", fontsize = 36)
p.axes.tick_params(labelrotation = 90, labelsize = 20)
p.axes.set_xlabel('Season', size = 24)
p.axes.set_ylabel('Goals', size = 24)
for container in p.containers:
    p.bar_label (container, label_type = 'edge', padding = -20, size = 20) #7abit itala3li el but bethabet
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.set(rc={'figure.figsize':(20,8)})
plt.xticks(rotation = 90, fontsize = 16)
p = sns.countplot(events['Year'], hue_order = events.groupby('Competition'))
p.axes.set_title("Goals per Year", fontsize = 36)
p.axes.tick_params(labelrotation = 90, labelsize = 20)
p.axes.set_xlabel('Year', size = 24)
p.axes.set_ylabel('Goals', size = 24)
for container in p.containers:
    p.bar_label(container, label_type = 'edge', padding = -20, size = 20) #nefs problem eli 9ablou
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
months = pd.Series({'January': 93, 'February': 77, 'March': 91, 'April': 68, 'May': 53, 'June': 7, 'July': 3, 'August': 35,
                    'September': 70, 'October': 53, 'November': 69, 'December': 53})
fig, ax = plt.subplots(figsize = (18, 8))
ax.bar(months.index, months.values, color = ['#2a4858', '#08737f', '#215d6e', '#39b48e', '#64c987', '#c4ec74', '#fafa6e',
                                             '#92dc7e', '#00898a', '#64c987', '#089f8f', '#64c987'])
plt.title('Goals Distribution over Months', size = 36)
plt.xlabel('Month', size = 24)
plt.ylabel('Goals', size = 24)
plt.xticks(rotation = 90, size = 20)
plt.yticks(size = 20)
plt.show()

# %%
sns.set(rc={'figure.figsize':(20,8)})
plt.xticks(rotation = 90, fontsize = 16)
p = sns.countplot(events['Month'], order = ['January', 'February', 'March', 'April', 'May', 'June',
                                        'July', 'August', 'September', 'October', 'November', 'December'])
p.axes.set_title("Goals per Month", fontsize = 36)
p.axes.tick_params(labelrotation = 90, labelsize = 20)
p.axes.set_xlabel('Year', size = 24)
p.axes.set_ylabel('Goals', size = 24)
for container in p.containers:
    p.bar_label(container, label_type = 'edge', padding = -20, size = 20)
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Fonction qui sera utilisée

# %%
def func(pct, allvalues):
    absolute = int(pct / 100.*np.sum(allvalues))
    return "{:.1f}%\n({:d} g)".format(pct, absolute)

# %%
fig, axes = plt.subplots(1, 2, figsize=(20,8))
fig.suptitle('Distribution of the Goals in the competitions', size = 36)

sns.countplot(events['Competition'], ax = axes[0], palette = "rocket");
axes[0].set_xlabel('Competition', size=24)
axes[0].set_ylabel('No. of Goals', size=24)
axes[0].tick_params(labelrotation = 90, labelsize = 20)
axes[0].spines['bottom'].set_color('black')
axes[0].spines['left'].set_color('black')
axes[0].spines['top'].set_color('black')
axes[0].spines['right'].set_color('black')

competition = events.Competition.value_counts().sort_values(ascending = False)
axes[1].pie(competition.values, explode = (0.1, 0.2, 0.3, 0.5, 0.7, 0.9), labels = competition.index, shadow = True,
            colors = ['#08737f', '#00898a', '#089f8f', '#39b48e', '#64c987', '#92dc7e'],
            textprops = {'family':'sans-serif', 'fontsize':'large', 'fontstyle':'italic', 'fontweight':'heavy'},
            autopct = lambda pct: func(pct, competition.values));
plt.show()
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
fig, axes = plt.subplots(1, 2, figsize=(20,8))

UCL_Goals = pd.Series({'Final': 2, 'Semi-Finals': 6, 'Quarter-Finals': 12, 'Last 16': 29, 'Group Stage': 71})
axes[0].pie(UCL_Goals.values, labels = UCL_Goals.index, explode = (0.5, 0.3, 0.1, 0.05, 0.05), shadow = True,
            autopct = lambda pct: func(pct, UCL_Goals.values),
            colors = ['#c4ec74', '#64c987', '#089f8f', '#08737f', '#2a4858'],
            textprops = {'family':'sans-serif', 'fontsize':'large', 'fontstyle':'italic', 'fontweight':'heavy'});
axes[0].set_title('UEFA Champions League', fontsize = 20);


Copa_Goals = pd.Series({'Final': 9, 'Semi-Finals': 11, 'Quarter-Finals': 11, 'Last 16': 22, 'Others': 3})
axes[1].pie(Copa_Goals.values, labels = Copa_Goals.index, explode = (0.05, 0.05, 0.05, 0.05, 0.05), shadow = True,
            autopct = lambda pct: func(pct, Copa_Goals.values),
            colors = ['#39b48e', '#00898a', '#00898a', '#215d6e', '#fafa6e'],
            textprops = {'family':'sans-serif', 'fontsize':'large', 'fontstyle':'italic', 'fontweight':'heavy'});
axes[1].set_title('Copa del Rey', fontsize = 20);

# %%
Place = events.Venue.value_counts()
fig, ax = plt.subplots(figsize = (12, 8))
ax.pie(Place.values, labels = ['Home', 'Away'], shadow = True, autopct = lambda pct: func(pct, Place.values),
       colors = ['#08737f', '#92dc7e'],
       textprops = {'family':'sans-serif', 'fontsize':'x-large', 'fontstyle':'italic', 'fontweight':'heavy'});
plt.title('Distribution of the Goals between Home and Away', size = 24)
plt.legend(['Home', 'Away'])
plt.show()

# %%
sns.set(rc={'figure.figsize':(10,5)})
plt.xticks(fontsize = 16)
p=sns.countplot(events['Playing_Position'], palette = 'cool',
                order = events.Playing_Position.value_counts().sort_values(ascending=False).index)
p.axes.set_title("Goals per Playing Position", fontsize = 36)
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Goals per Playing Position')

# %%
fig, axes = plt.subplots(1, 2, figsize=(20,8))

Top_Victims = events.Opponent.value_counts()[:13].sort_values()
axes[0].barh(Top_Victims.index, Top_Victims.values, color = ['#fafa6e', '#c4ec74' ,'#92dc7e', '#64c987', '#39b48e',
                                                                   '#39b48e', '#089f8f', '#089f8f', '#00898a', '#08737f',
                                                                   '#215d6e', '#215d6e', '#2a4858'])
axes[0].set_title('The most Teams Messi scored against', fontsize = 25)
axes[0].set_xlabel('No. of Goals', size = 24)
axes[0].set_ylabel('Team', size = 24)
plt.locator_params('x', nbins = 20)
axes[0].tick_params(labelsize = 20)

opponent_UCL = events[events.Competition == 'UEFA Champions League'].Opponent.value_counts()
x = dict(opponent_UCL)
opponent_UCL = pd.Series(x)
Top_Victims_UCL = opponent_UCL[:13].sort_values()
axes[1].barh(Top_Victims_UCL.index, Top_Victims_UCL.values, color = ['#fafa6e', '#c4ec74', '#c4ec74', '#92dc7e',
                                                                           '#64c987', '#64c987', '#64c987', '#39b48e',
                                                                           '#089f8f', '#00898a', '#08737f', '#215d6e',
                                                                           '#2a4858'])
axes[1].set_title('The most Teams Messi scored against in UCL', fontsize = 25)
axes[1].set_xlabel('No. of Goals', size = 24)
axes[1].set_ylabel('Team', size = 24)
plt.locator_params('x', nbins = 10)
axes[1].tick_params(labelsize = 20)
plt.show()

# %%
Assisters = events.Goal_assist.value_counts()
fig, ax = plt.subplots(figsize = (12, 8))
ax.bar(Assisters[:11].index, Assisters[:11].values, color = ['#2a4858', '#215d6e', '#08737f', '#00898a', '#089f8f', '#39b48e',
                                                             '#64c987', '#92dc7e', '#92dc7e', '#c4ec74', '#fafa6e'])
plt.title('Most Players to Assist Messi', size = 36)
plt.xlabel('Player', size = 24)
plt.ylabel('No. of Assists', size = 24)
plt.xticks(rotation = 75, size = 16)
plt.yticks(size = 20)
plt.show()
